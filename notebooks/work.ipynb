# %% [markdown]
# # Рабочий ноутбук

# %% [markdown]
# Соберем все что нам нужно

# %%
import os
from dotenv import load_dotenv
from pyspark.sql import SparkSession

# Загрузка переменных окружения
env_path = os.path.join("..", ".env")
load_dotenv(env_path)

# Пути к данным
output_data_path = os.path.join("..", "data", "output_data")

# Создание сессии Spark
spark = SparkSession.builder.appName("SimpleApp").getOrCreate()
# Out:
# 25/12/17 21:24:58 WARN Utils: Your hostname, ono-workstation resolves to a loopback address: 127.0.1.1; using 192.168.31.144 instead (on interface wlp62s0)
# 25/12/17 21:24:58 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/12/17 21:24:59 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# Скачаем данные

# %%
# !s3cmd get --recursive --force s3://{os.getenv("S3_BUCKET_NAME")}/output_data/ {output_data_path}/
# Out:
# download: 's3://airflow-bucket-a6191da289dc80d5/output_data/sum_data.parquet/_SUCCESS' -> '../data/output_data/sum_data.parquet/_SUCCESS'  [1 of 3]
#  0 of 0     0% in    0s     0.00 B/s  done
# download: 's3://airflow-bucket-a6191da289dc80d5/output_data/sum_data.parquet/part-00000-4836c334-4e53-4653-8cb6-b71e30845397-c000.snappy.parquet' -> '../data/output_data/sum_data.parquet/part-00000-4836c334-4e53-4653-8cb6-b71e30845397-c000.snappy.parquet'  [2 of 3]
#  304 of 304   100% in    0s  1096.10 B/s  done
# download: 's3://airflow-bucket-a6191da289dc80d5/output_data/sum_data.parquet/part-00001-4836c334-4e53-4653-8cb6-b71e30845397-c000.snappy.parquet' -> '../data/output_data/sum_data.parquet/part-00001-4836c334-4e53-4653-8cb6-b71e30845397-c000.snappy.parquet'  [3 of 3]
#  475 of 475   100% in    0s  1682.96 B/s  done

# %% [markdown]
# Прочитаем результат

# %%
df = spark.read.parquet(os.path.join(output_data_path, "sum_data.parquet"))
df.show()
# Out:
# +------+
# |result|
# +------+
# |     4|
# |     4|
# +------+
